# %%
# %load_ext sql
# %sql mysql://root:Happy_Unicorn312@localhost/sakila
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Traceback (most recent call last):
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in create_engine
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\create.py", line 599, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py", line 147, in import_dbapi
#     return __import__("MySQLdb")
#            ^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'MySQLdb'
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Traceback (most recent call last):
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in create_engine
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\create.py", line 599, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py", line 147, in import_dbapi
#     return __import__("MySQLdb")
#            ^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'MySQLdb'
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# CREATE DATABASE PizzaProject
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# USE PizzaProject
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# SET FOREIGN_KEY_CHECKS = 0;
#
# DROP TABLE IF EXISTS OrderItem;
# DROP TABLE IF EXISTS OrderDelivery;
# DROP TABLE IF EXISTS `Order`;
# DROP TABLE IF EXISTS CustomerDeliveryAddress;
# DROP TABLE IF EXISTS Customer;
# DROP TABLE IF EXISTS DeliveryAddress;
# DROP TABLE IF EXISTS DeliveryPersonArea;
# DROP TABLE IF EXISTS Area;
# DROP TABLE IF EXISTS IngredientList;
# DROP TABLE IF EXISTS Item;
# DROP TABLE IF EXISTS IngredientType;
# DROP TABLE IF EXISTS Ingredient;
# DROP TABLE IF EXISTS RestrictionType;
# DROP TABLE IF EXISTS DeliveryPerson;
# DROP TABLE IF EXISTS Account;
#
# SET FOREIGN_KEY_CHECKS = 1;
#
# CREATE TABLE Account (
#     AccountID INT PRIMARY KEY AUTO_INCREMENT,
#     Username NVARCHAR(40) NOT NULL UNIQUE,
#     Password NVARCHAR(40) NOT NULL
# );
#
# CREATE TABLE Customer (
#     CustomerID INT PRIMARY KEY AUTO_INCREMENT,
#     FirstName NVARCHAR(40),
#     LastName NVARCHAR(40),
#     Gender CHAR(1),
#     Birthdate DATE,
#     Phone NVARCHAR(15),
#     NumerOfPizzas INT,
#     AccountID INT,
#     FOREIGN KEY (AccountID) REFERENCES Account(AccountID)
# );
#
# CREATE TABLE Area (
#     AreaID INT PRIMARY KEY AUTO_INCREMENT,
#     PostalCode NVARCHAR(15) NOT NULL UNIQUE
# );
#
# CREATE TABLE DeliveryAddress(
#     DeliveryAddressID INT PRIMARY KEY AUTO_INCREMENT,
#     StreetName NVARCHAR(40),
#     HouseNumber NVARCHAR(40),
#     PostalCode NVARCHAR(15) NOT NULL,
#     FOREIGN KEY (PostalCode) REFERENCES Area(PostalCode)
# );
#
# CREATE TABLE CustomerDeliveryAddress(
#     DeliveryAddressID INT,
#     CustomerID INT,
#     PRIMARY KEY (CustomerID, DeliveryAddressID),
#     FOREIGN KEY (CustomerID) REFERENCES Customer(CustomerID),
#     FOREIGN KEY (DeliveryAddressID) REFERENCES DeliveryAddress(DeliveryAddressID)
# );
#
# CREATE TABLE `Order`(
#     OrderID INT PRIMARY KEY AUTO_INCREMENT,
#     CustomerID INT,
#     DeliveryAddressID INT,
#     OrderStatus ENUM('In processing', 'Being Prepared', 'On the way', 'Delivered') DEFAULT 'In processing',
#     FOREIGN KEY (CustomerID) REFERENCES Customer(CustomerID),
#     FOREIGN KEY (DeliveryAddressID) REFERENCES DeliveryAddress(DeliveryAddressID)
# );
#
# CREATE TABLE Item(
#     ItemID INT PRIMARY KEY AUTO_INCREMENT,
#     ItemName NVARCHAR(40),
#     ItemType ENUM('Pizza', 'Drink', 'Dessert')
# );
#
# CREATE TABLE OrderItem(
#     OrderID INT,
#     ItemID INT,
#     Quantity INT,
#     PRIMARY KEY (OrderID, ItemID),
#     FOREIGN KEY (OrderID) REFERENCES `Order`(OrderID),
#     FOREIGN KEY (ItemID) REFERENCES Item(ItemID)
# );
#
# CREATE TABLE Ingredient (
#     IngredientID INT PRIMARY KEY AUTO_INCREMENT,
#     IngredientName NVARCHAR(100) NOT NULL,
#     Price DECIMAL(10, 2) NOT NULL
# );
#
# CREATE TABLE IngredientList (
#     IngredientListID INT PRIMARY KEY AUTO_INCREMENT,
#     ItemID INT,
#     IngredientID INT,
#     FOREIGN KEY (ItemID) REFERENCES Item(ItemID),
#     FOREIGN KEY (IngredientID) REFERENCES Ingredient(IngredientID)
# );
#
# CREATE TABLE RestrictionType (
#     RestrictionTypeID INT PRIMARY KEY AUTO_INCREMENT,
#     Vegan BIT,
#     Vegetarian BIT,
#     GlutenFree BIT,
#     LactoseFree BIT
# );
#
# CREATE TABLE IngredientType (
#     IngredientID INT,
#     RestrictionTypeID INT,
#     PRIMARY KEY (IngredientID, RestrictionTypeID),
#     FOREIGN KEY (IngredientID) REFERENCES Ingredient(IngredientID),
#     FOREIGN KEY (RestrictionTypeID) REFERENCES RestrictionType(RestrictionTypeID)
# );
#
# CREATE TABLE DeliveryPerson (
#     DeliveryPersonID INT PRIMARY KEY AUTO_INCREMENT,
#     Availability ENUM('Available', 'Not available')
# );
#
# CREATE TABLE DeliveryPersonArea (
#     DeliveryPersonID INT,
#     AreaID INT,
#     PRIMARY KEY (DeliveryPersonID, AreaID),
#     FOREIGN KEY (DeliveryPersonID) REFERENCES DeliveryPerson(DeliveryPersonID),
#     FOREIGN KEY (AreaID) REFERENCES Area(AreaID)
# );
#
# CREATE TABLE OrderDelivery (
#     OrderID INT,
#     DeliveryPersonID INT,
#     DeliveryStartTime DATETIME,
#     EstimatedDeliveryTime DATETIME,
#     PRIMARY KEY (OrderID, DeliveryPersonID),
#     FOREIGN KEY (OrderID) REFERENCES `Order`(OrderID),
#     FOREIGN KEY (DeliveryPersonID) REFERENCES DeliveryPerson(DeliveryPersonID)
# );
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Home1\AppData\Local\Programs\Python\Python312\Lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
